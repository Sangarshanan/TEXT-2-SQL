# %%
from flask import Flask
from flask import request
from flask import render_template
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import numpy as np
import matplotlib.pyplot as plt
import MySQLdb
from pandas.io import sql
from sqlalchemy import create_engine
import re
from chatterbot import ChatBot
from chatterbot.trainers import ChatterBotCorpusTrainer

# %% [markdown]
# **CONVERT CSV INTO A PANDAS DATAFRAME AND REMOVING UNWANTED COLUMNS**

# %%
data = pd.read_csv('cleanedmrdata.csv',error_bad_lines=False, engine= 'python')
data= pd.DataFrame(data)
df = data.drop(['CurrentAffairs','Education','Music','Philosophy','PoliticalScience','Science','History','Law','Games','Books','FoodandDrink','DataSource','WebTech','Economics','Medicine'], axis=1)
df.head()
# Out:
#           author  comment.count           date  \
# 0    Tyler Cowen           27.0  January1,2010
# 1    Tyler Cowen           18.0  January1,2010
# 2  Alex Tabarrok            8.0  January1,2010
# 3    Tyler Cowen           28.0  January1,2010
# 4    Tyler Cowen            8.0  January1,2010
#
#                                                 text  \
# 0  Matt Yglesias calculates:\n\nÃ¢â‚¬Â¦monitoring...
# 1  Today is Public Domain day and James Boyle rep...
# 2  Is there any drug that helps more conditions w...
# 3  \nAs of January 1, 2010, we are changing our n...
# 4  From Joanne McNeil, this is one of my favorite...
#
#                                  title  wordcount                 time
# 0       Terrorists and false positives      133.0  2016-09-17 16:23:00
# 1                    Public Domain Day      224.0  2016-09-17 12:18:00
# 2      Markets in Everything: Placebos       32.0  2016-09-17 10:59:00
# 3  Peter BoettkeÃ¢â‚¬â„¢s announcement      127.0  2016-09-17 09:35:00
# 4               How to capture an idea      294.0  2016-09-17 05:12:00

# %% [markdown]
# **ADD THE DATAFRAME TO MYSQL DATABASE USING SQLACHEMY**

# %%
engine = create_engine("mysql://root:@localhost/data"'?charset=utf8')
df.to_sql(name='chatbot', con=engine,flavor=None, schema=None, if_exists='replace', index=True, index_label=None, chunksize=None, dtype=None)
# Out:
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ev...' for column 'text' at row 11")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ev...' for column 'text' at row 20")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD th...' for column 'text' at row 21")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD th...' for column 'text' at row 25")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD in...' for column 'text' at row 2")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD a ...' for column 'text' at row 3")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD wh...' for column 'text' at row 12")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD to...' for column 'text' at row 22")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD wh...' for column 'text' at row 39")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD th...' for column 'text' at row 45")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD el...' for column 'text' at row 55")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD cr...' for column 'text' at row 5")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD al...' for column 'text' at row 10")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD wi...' for column 'text' at row 17")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD be...' for column 'text' at row 19")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD tr...' for column 'text' at row 25")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD th...' for column 'text' at row 26")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD al...' for column 'text' at row 36")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD hi...' for column 'text' at row 47")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD an...' for column 'text' at row 1")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD it...' for column 'text' at row 11")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ca...' for column 'text' at row 32")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD fu...' for column 'text' at row 36")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD th...' for column 'text' at row 38")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD if...' for column 'text' at row 51")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD th...' for column 'text' at row 2")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD to...' for column 'text' at row 6")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD Bo...' for column 'text' at row 10")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD th...' for column 'text' at row 11")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD in...' for column 'text' at row 21")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD at...' for column 'text' at row 30")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD an...' for column 'text' at row 33")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD Cl...' for column 'text' at row 37")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD it...' for column 'text' at row 48")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD do...' for column 'text' at row 54")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ot...' for column 'text' at row 56")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD if...' for column 'text' at row 19")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD wh...' for column 'text' at row 24")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ev...' for column 'text' at row 38")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, 'Incorrect string value: \'\\xEF\\xBF\\xBD "_...\' for column \'text\' at row 43')
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD wh...' for column 'text' at row 49")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD es...' for column 'text' at row 51")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ho...' for column 'text' at row 54")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD in...' for column 'text' at row 55")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD po...' for column 'text' at row 10")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD in...' for column 'text' at row 16")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD in...' for column 'text' at row 35")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD in...' for column 'text' at row 42")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD in...' for column 'text' at row 47")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD wh...' for column 'text' at row 51")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD am...' for column 'text' at row 59")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD th...' for column 'text' at row 6")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD fo...' for column 'text' at row 10")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD al...' for column 'text' at row 23")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD an...' for column 'text' at row 29")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD pl...' for column 'text' at row 31")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD-\\x0AI...' for column 'text' at row 32")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD Fi...' for column 'text' at row 49")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD na...' for column 'text' at row 4")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ye...' for column 'text' at row 7")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD or...' for column 'text' at row 8")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD an...' for column 'text' at row 20")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD hy...' for column 'text' at row 24")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ha...' for column 'title' at row 36")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, 'Incorrect string value: \'\\xEF\\xBF\\xBD "T...\' for column \'text\' at row 54')
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD wh...' for column 'text' at row 64")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD no...' for column 'text' at row 14")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ra...' for column 'text' at row 18")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD bo...' for column 'text' at row 19")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD go...' for column 'text' at row 20")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD be...' for column 'text' at row 25")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD co...' for column 'text' at row 31")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD Mi...' for column 'text' at row 35")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD \\xC3\\x83...' for column 'text' at row 49")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD in...' for column 'text' at row 60")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD pu...' for column 'text' at row 1")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ma...' for column 'text' at row 10")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD pe...' for column 'text' at row 19")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD in...' for column 'text' at row 27")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD no...' for column 'text' at row 29")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD be...' for column 'text' at row 30")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD so...' for column 'title' at row 31")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD da...' for column 'text' at row 32")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD at...' for column 'text' at row 35")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD he...' for column 'text' at row 39")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD an...' for column 'text' at row 42")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD wh...' for column 'text' at row 54")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD im...' for column 'text' at row 4")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD mo...' for column 'text' at row 34")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD po...' for column 'text' at row 35")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD no...' for column 'text' at row 62")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD na...' for column 'text' at row 30")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD bo...' for column 'text' at row 44")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD or...' for column 'text' at row 48")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD sh...' for column 'text' at row 2")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD al...' for column 'text' at row 34")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD wi...' for column 'text' at row 44")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD no...' for column 'text' at row 45")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD no...' for column 'text' at row 51")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD an...' for column 'text' at row 16")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD sl...' for column 'text' at row 19")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD th...' for column 'text' at row 27")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD th...' for column 'text' at row 32")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD a ...' for column 'text' at row 43")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD po...' for column 'text' at row 3")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD at...' for column 'text' at row 7")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD $7...' for column 'text' at row 8")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD mo...' for column 'text' at row 16")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD th...' for column 'text' at row 52")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD wh...' for column 'text' at row 21")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD in...' for column 'text' at row 33")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD a ...' for column 'text' at row 36")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD in...' for column 'text' at row 39")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD if...' for column 'text' at row 45")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD wh...' for column 'text' at row 4")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD wh...' for column 'text' at row 18")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD at...' for column 'text' at row 20")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD fo...' for column 'text' at row 22")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD I ...' for column 'text' at row 33")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD wh...' for column 'text' at row 40")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD Ja...' for column 'text' at row 43")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBDwou...' for column 'text' at row 47")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD sw...' for column 'text' at row 50")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD th...' for column 'text' at row 1")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD se...' for column 'text' at row 4")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD a ...' for column 'text' at row 9")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD Ha...' for column 'text' at row 16")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD Lu...' for column 'text' at row 26")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD wh...' for column 'text' at row 28")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ye...' for column 'text' at row 31")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD is...' for column 'text' at row 33")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD th...' for column 'text' at row 37")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD or...' for column 'text' at row 38")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD an...' for column 'text' at row 3")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD or...' for column 'text' at row 6")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD Vi...' for column 'text' at row 15")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD or...' for column 'text' at row 19")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD Th...' for column 'text' at row 49")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD no...' for column 'text' at row 9")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD mo...' for column 'text' at row 15")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD th...' for column 'text' at row 20")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD if...' for column 'text' at row 21")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD wo...' for column 'title' at row 22")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD wi...' for column 'text' at row 27")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ca...' for column 'title' at row 29")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD wi...' for column 'text' at row 32")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD bu...' for column 'text' at row 33")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD co...' for column 'text' at row 1")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ye...' for column 'text' at row 5")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ev...' for column 'text' at row 10")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD yo...' for column 'text' at row 14")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD na...' for column 'text' at row 27")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ho...' for column 'title' at row 30")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, 'Incorrect string value: \'\\xEF\\xBF\\xBD "A...\' for column \'text\' at row 40')
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ev...' for column 'text' at row 42")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD im...' for column 'text' at row 46")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ou...' for column 'text' at row 19")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD no...' for column 'text' at row 36")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD or...' for column 'text' at row 7")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ch...' for column 'text' at row 31")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD fl...' for column 'text' at row 44")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ac...' for column 'text' at row 45")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD wh...' for column 'text' at row 1")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD th...' for column 'text' at row 7")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ev...' for column 'text' at row 12")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD in...' for column 'text' at row 30")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD to...' for column 'text' at row 37")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD in...' for column 'text' at row 3")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD af...' for column 'text' at row 6")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ar...' for column 'text' at row 10")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD sm...' for column 'text' at row 31")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ch...' for column 'text' at row 43")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD an...' for column 'text' at row 48")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ab...' for column 'text' at row 49")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD cl...' for column 'text' at row 17")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ma...' for column 'text' at row 20")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD FO...' for column 'text' at row 2")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD it...' for column 'text' at row 3")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD a ...' for column 'text' at row 4")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD an...' for column 'text' at row 14")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD in...' for column 'text' at row 25")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD we...' for column 'text' at row 30")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD le...' for column 'text' at row 46")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD re...' for column 'text' at row 3")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD as...' for column 'text' at row 14")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD es...' for column 'text' at row 19")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD so...' for column 'text' at row 43")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD wi...' for column 'text' at row 1")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ma...' for column 'text' at row 2")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD to...' for column 'text' at row 4")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD\\x0AI ...' for column 'text' at row 14")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD me...' for column 'text' at row 23")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD in...' for column 'text' at row 43")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD Be...' for column 'text' at row 45")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD Fo...' for column 'title' at row 57")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, 'Incorrect string value: \'\\xEF\\xBF\\xBD "t...\' for column \'text\' at row 8')
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD\\xC3\\x83\\xE2...' for column 'text' at row 18")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD mo...' for column 'text' at row 22")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD th...' for column 'text' at row 23")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ab...' for column 'text' at row 34")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD cl...' for column 'text' at row 43")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD qu...' for column 'title' at row 15")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ov...' for column 'text' at row 19")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD re...' for column 'text' at row 27")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD on...' for column 'text' at row 28")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD an...' for column 'text' at row 37")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD as...' for column 'text' at row 38")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD wo...' for column 'text' at row 48")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD $6...' for column 'text' at row 9")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD th...' for column 'text' at row 36")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD it...' for column 'text' at row 1")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD Th...' for column 'text' at row 8")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD an...' for column 'text' at row 21")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD th...' for column 'text' at row 31")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD he...' for column 'text' at row 37")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD bu...' for column 'text' at row 2")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD or...' for column 'text' at row 14")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD an...' for column 'text' at row 17")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD be...' for column 'text' at row 26")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD to...' for column 'text' at row 41")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ov...' for column 'text' at row 57")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD fo...' for column 'text' at row 20")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD an...' for column 'text' at row 34")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD Bu...' for column 'text' at row 44")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD th...' for column 'text' at row 50")
#   rows += self.execute(sql + postfix)
# ...
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBDwhi...' for column 'text' at row 24")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBDreg...' for column 'text' at row 29")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBDat ...' for column 'text' at row 30")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ap...' for column 'text' at row 38")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD mo...' for column 'text' at row 17")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ma...' for column 'text' at row 32")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBDthe...' for column 'text' at row 33")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD so...' for column 'text' at row 13")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD da...' for column 'text' at row 22")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD me...' for column 'text' at row 32")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBDmor...' for column 'text' at row 35")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD\\xC3\\x83\\xE2...' for column 'text' at row 4")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD si...' for column 'text' at row 7")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD is...' for column 'text' at row 9")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ro...' for column 'title' at row 34")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD la...' for column 'text' at row 36")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBDgen...' for column 'text' at row 1")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBDeve...' for column 'text' at row 3")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD\\xC3\\x83\\xC2...' for column 'text' at row 10")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBDthi...' for column 'text' at row 12")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD my...' for column 'text' at row 17")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD an...' for column 'text' at row 27")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD es...' for column 'text' at row 38")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBDand...' for column 'text' at row 16")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD72\\xC3...' for column 'text' at row 20")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD la...' for column 'text' at row 21")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD al...' for column 'text' at row 26")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD em...' for column 'text' at row 27")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD pa...' for column 'text' at row 39")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD if...' for column 'text' at row 40")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD Je...' for column 'text' at row 8")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD \\xC3\\x83...' for column 'text' at row 14")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBDpar...' for column 'text' at row 15")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD al...' for column 'text' at row 30")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD de...' for column 'text' at row 32")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ab...' for column 'text' at row 41")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD\\xC3\\x83\\xC2...' for column 'text' at row 5")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD it...' for column 'text' at row 25")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD wa...' for column 'text' at row 32")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ne...' for column 'text' at row 36")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBDsuc...' for column 'text' at row 1")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD mo...' for column 'text' at row 3")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD se...' for column 'text' at row 5")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD le...' for column 'text' at row 16")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD\\xC3\\x83\\xC2...' for column 'text' at row 20")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD Ma...' for column 'text' at row 26")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ef...' for column 'text' at row 27")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ev...' for column 'text' at row 34")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD\\xC3\\x83\\xE2...' for column 'text' at row 37")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD li...' for column 'text' at row 40")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD\\xC3\\x83\\xC2...' for column 'text' at row 3")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBDthe...' for column 'text' at row 15")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ev...' for column 'text' at row 16")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ta...' for column 'text' at row 22")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBDpay...' for column 'text' at row 34")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBDtha...' for column 'text' at row 38")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD Bl...' for column 'text' at row 3")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD mo...' for column 'text' at row 4")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD\\xC3\\x83\\xC2...' for column 'text' at row 11")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBDa c...' for column 'text' at row 16")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD95 ...' for column 'text' at row 35")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD di...' for column 'text' at row 10")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD I ...' for column 'text' at row 27")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBDtho...' for column 'text' at row 28")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:313: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD di...' for column 'text' at row 33")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:318: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD bu...' for column 'text' at row 1")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:318: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBDwhi...' for column 'text' at row 3")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:318: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD le...' for column 'text' at row 17")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:318: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD ha...' for column 'text' at row 23")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:318: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD do...' for column 'text' at row 28")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:318: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD it...' for column 'text' at row 29")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:318: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD th...' for column 'text' at row 31")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:318: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBDsur...' for column 'text' at row 38")
#   rows += self.execute(sql + postfix)
# C:\Users\Sangarshanan Veera\Anaconda3\lib\site-packages\MySQLdb\cursors.py:318: Warning: (1366, "Incorrect string value: '\\xEF\\xBF\\xBD to...' for column 'text' at row 42")
#   rows += self.execute(sql + postfix)

# %% [markdown]
# **CLEAN TEXT INPUT**

# %%
stops = set(stopwords.words("english"))
def cleanData(text):
    txt = str(text)
    txt = re.sub(r'[^A-Za-z0-9\s]',r'',txt)
    txt = re.sub(r'\n',r' ',txt) #instead of newline we input corpus with a space 
    txt = " ".join([w.lower() for w in txt.split()])  #convert to lowercase
    txt = " ".join([w for w in txt.split() if w not in stops]) #remove stopwords
    return txt

# %%
db = MySQLdb.connect("localhost","root","","data" )
title = "Public Domain Day"
query = "SELECT author from chatbot where title ='" + title + "';"
cursor = db.cursor()
cursor.execute(query)
results = cursor.fetchall()
print(results[0][0])
# Out:
# Tyler Cowen

# %%
text = "which author wrote with the title Public Domain Day"
a= ['author','title','wrote']
text = cleanData(text)
k = text.split(" ")
k.remove(a[0])
k.remove(a[1])
k.remove(a[2])
k = ' '.join(k)
k = str(k)
print (k)
query = "SELECT author from chatbot where title ='" + k + "';"
cursor = db.cursor()
cursor.execute(query)
results = cursor.fetchall()
print (results[0][0])
# Out:
# public domain day
# Tyler Cowen

# %% [markdown]
# **CONVERT NATURAL LANGUAGE TO QUERY**

# %%
app = Flask(__name__)

chatbot.train("chatterbot.corpus.english")

@app.route('/')
def my_form():
    return render_template("index.html")

@app.route('/', methods=['POST'])
def my_form_post():

    txt = request.form['text']
    txt = cleanData(txt)
    txt = str(txt)
    txt = txt.split(" ")
    col = ['author','comment','date','text','title','wordcount','time','number','count','word']
    k = list(set(txt).intersection(col))
    if len(k) ==0:
        return str(chatbot.get_response(txt))
    else:
        a= ['author','title','wrote']
        if  len(set(a).intersection(set(txt))) > 0:
            text = request.form['text']
            text = cleanData(text)
            k = text.split(" ")
            k.remove(a[0])
            k.remove(a[1])
            k.remove(a[2])
            k = " ".join(k)
            k=str(k)
            query = "SELECT author from chatbot where title ='" + k + "';"
            cursor = db.cursor()
            cursor.execute(query)
            results = cursor.fetchall()
            return results[0][0]
            
        
    
    
    


    
    

if __name__ == '__main__':
    app.run()
# Out:
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [07/Dec/2017 19:32:12] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Dec/2017 19:32:18] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Dec/2017 19:48:15] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Dec/2017 20:02:14] "POST / HTTP/1.1" 200 -
